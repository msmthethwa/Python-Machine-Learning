# %% [markdown]
# Given this data, you need to build a machine learning for HR department that can help them decide salaries for future candidates. Using this predict salaries for following candidates: 2 yr experience, 9 test score, 6 interview score; 12 yr experience, 10 test score, 10 interview score.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from word2number import w2n

# %%
df = pd.read_csv('hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
#handle the missing values for 'test_score(out of 10)'
import math

# %%
medianT = math.floor(df[['test_score(out of 10)']].median())
medianT
# Out:
# C:\Users\MS Mthethwa\AppData\Local\Temp\ipykernel_16972\745918230.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   medianT = math.floor(df[['test_score(out of 10)']].median())
# 8

# %%
df[['test_score(out of 10)']] = df[['test_score(out of 10)']].fillna(medianT)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    8.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
#handle the missing values for 'experience'
df.experience = df.experience.fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    8.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    8.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
#Prepare the data
#Feature: experience, test_score(out of 10), interview_score(out of 10)
x = df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']] 
#Target: salary
y = df['salary($)']

# %%
#Create linear regression model
model = LinearRegression()

# %%
#Fit the model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
salaryToPredict = np.array([[2,9,6]])
predictedSalary = model.predict(salaryToPredict)
# Out:
# C:\Users\MS Mthethwa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predictedSalary
# Out:
# array([53205.96797671])

# %%
model.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
model.intercept_
# Out:
# np.float64(17737.263464337688)

# %%
#price = m1 * experience + m2 * test_score(out of 10) + m3 * interview_score(out of 10) + b
2812.95487627 * 2 + 1845.70596798 * 9 + 2205.24017467 * 6 + 17737.263464337688
# Out:
# 53205.96797671769
